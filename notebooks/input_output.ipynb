# %%
 # upgrade gspraed if necessary
# !pip install --upgrade -q gspread

# %%
import gspread
from google.colab import auth
from oauth2client.client import GoogleCredentials
from gspread_dataframe import set_with_dataframe

auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())

from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
# Conecto con el Excel en Google
worksheet = gc.open('My Drive/challenge-1-desarrollo/data/input').sheet1

# Extraigo los registros
rows = worksheet.get_all_values()

# Convierto a DataFrame
df = pd.DataFrame.from_records(rows)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/gspread/client.py in open(self, title)
#     118                 lambda x: x['name'] == title,
# --> 119                 self.list_spreadsheet_files(title),
#     120             )
#
# /usr/local/lib/python3.6/dist-packages/gspread/utils.py in finditem(func, seq)
#      96     """
# ---> 97     return next((item for item in seq if func(item)))
#      98
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# SpreadsheetNotFound                       Traceback (most recent call last)
# <ipython-input-9-e301c40d3ed3> in <module>()
#       1 # Conecto con el Excel en Google
# ----> 2 worksheet = gc.open('My Drive/challenge-1-desarrollo/data/input').sheet1
#       3
#       4 # Extraigo los registros
#       5 rows = worksheet.get_all_values()
#
# ...

# %%
df.head()
# Out:
#     0        1
# 0  ID  Juzgado
# 1   1        A
# 2   2        B
# 3   3        C
# 4   4        D

# %%
# Definimos el titulo de salida
title = 'output'

# Creamos el titulo
gc.create(title)  # if not exist

# Abre temporalmente el archivo nuevo
sheet = gc.open('/gdrive/challenge-1-desarrollo/'+ title).sheet1

# Guarda los datos
set_with_dataframe(sheet, df)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/gspread/client.py in open(self, title)
#     118                 lambda x: x['name'] == title,
# --> 119                 self.list_spreadsheet_files(title),
#     120             )
#
# /usr/local/lib/python3.6/dist-packages/gspread/utils.py in finditem(func, seq)
#      96     """
# ---> 97     return next((item for item in seq if func(item)))
#      98
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# SpreadsheetNotFound                       Traceback (most recent call last)
# <ipython-input-30-4a652f524cc3> in <module>()
#       6
#       7 # Abre temporalmente el archivo nuevo
# ----> 8 sheet = gc.open('/gdrive/challenge-1-desarrollo/'+ title).sheet1
#       9
#      10 # Guarda los datos
#
# ...
